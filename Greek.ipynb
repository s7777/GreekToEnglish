# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	#re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			#line = normalize('NFD', line).encode('ascii', 'ignore')
			#line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			#line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			#line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
		#	line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'ell.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-Greek.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-Greek.pkl
# [Go] => [Πάμε]
# [Run] => [Τρέξε]
# [Run] => [Τρέξτε]
# [Who] => [Ποιος]
# [Wow] => [Ουάου]
# [Help] => [Βοήθεια]
# [Jump] => [Πήδα]
# [Hello] => [Γεια σας]
# [Hurry] => [Βιάσου]
# [I try] => [Προσπαθώ]
# [I won] => [Κέρδισα]
# [I won] => [Νίκησα]
# [Smile] => [Χαμογέλα]
# [Attack] => [Επίθεση]
# [Cheers] => [Στην υγειά μας]
# [I fell] => [Έπεσα]
# [I know] => [Ξέρω]
# [I left] => [Έφυγα]
# [I lied] => [Είπα ψέματα]
# [I lost] => [Έχασα]
# [Im OK] => [Είμαι εντάξει]
# [Im OK] => [Είμαι καλά]
# [Im OK] => [Καλά είμαι]
# [Listen] => [Άκου]
# [Really] => [Αλήθεια]
# [Thanks] => [Ευχαριστώ]
# [Try it] => [Δοκίμασε το]
# [Try it] => [Δοκιμάστε το]
# [We try] => [Προσπαθούμε]
# [We won] => [Νικήσαμε]
# [We won] => [Κερδίσαμε]
# [Why me] => [Γιατί εγώ]
# [Ask Tom] => [Ρώτα τον Τομ]
# [Ask Tom] => [Ρωτήστε τον Τομ]
# [Get out] => [Άντε φύγε]
# [Get out] => [Βγες έξω]
# [Get out] => [Βγείτε έξω]
# [Goodbye] => [Αντίο]
# [He came] => [Ήρθε]
# [He runs] => [Αυτός τρέχει]
# [Help me] => [Βοήθησέ με]
# [Help us] => [Βοήθησέ μας]
# [Help us] => [Βοηθήστε μας]
# [Hit Tom] => [Χτύπα τον Τομ]
# [Hit Tom] => [Χτυπήστε τον Τομ]
# [Hug Tom] => [Αγκάλιασε τον Τομ]
# [Hug Tom] => [Αγκαλιάστε τον Τομ]
# [I agree] => [Συμφωνώ]
# [I tried] => [Προσπάθησα]
# [Im Tom] => [Είμαι ο Τομ]
# [Im shy] => [Είμαι ντροπαλός]
# [Im shy] => [Είμαι ντροπαλή]
# [Me too] => [Κι εγώ]
# [Open up] => [Άνοιξε]
# [Perfect] => [Τέλεια]
# [Perfect] => [Υπέροχα]
# [See you] => [Τα λέμε]
# [See you] => [Τα λέμε]
# [Tom ate] => [Ο Τομ έφαγε]
# [Tom ran] => [Ο Τομ έτρεξε]
# [Tom won] => [Ο Τομ νίκησε]
# [Wash up] => [Πλύσου]
# [We lost] => [Χάσαμε]
# [Welcome] => [Καλώς ήρθατε]
# [Welcome] => [Καλώς όρισες]
# [Who ate] => [Ποιος έφαγε]
# [Who won] => [Ποιος νίκησε]
# [Who won] => [Ποιος κέρδισε]
# [Why not] => [Γιατί όχι]
# [You won] => [Κέρδισες]
# [You won] => [Κερδίσατε]
# [You won] => [Νίκησες]
# [You won] => [Νικήσατε]
# [Am I fat] => [Είμαι χοντρή]
# [Am I fat] => [Είμαι χοντρός]
# [Find Tom] => [Βρες τον Τομ]
# [Find Tom] => [Βρείτε τον Τομ]
# [Grab him] => [Άρπαξ τον]
# [Grab him] => [Άρπαξέ τον]
# [Grab him] => [Αρπάξτε τον]
# [Have fun] => [Καλή διασκέδαση]
# [He tries] => [Προσπαθεί]
# [Help Tom] => [Βοήθησε τον Τομ]
# [Help Tom] => [Βοηθήστε τον Τομ]
# [Hi guys] => [Γεια σας παιδιά]
# [How cute] => [Τι γλυκό]
# [How deep] => [Πόσο βαθιά]
# [Hurry up] => [Βιάσου]
# [I agreed] => [Συμφώνησα]
# [I failed] => [Απέτυχα]
# [I forgot] => [Ξέχασα]
# [I refuse] => [Αρνούμαι]
# [I resign] => [Παραιτούμαι]
# [I smiled] => [Χαμογέλασα]
# [I stayed] => [Έμεινα]
# [I use it] => [Το χρησιμοποιώ]
# [I waited] => [Περίμενα]
# [Ill pay] => [Την κερνάω εγώ]
# [Ill try] => [Θα προσπαθήσω]
# [Im busy] => [Είμαι απασχολημένος]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-Greek.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[1000:]
# save
save_clean_data(dataset, 'english-Greek-both.pkl')
save_clean_data(train, 'english-Greek-train.pkl')
save_clean_data(test, 'english-Greek-test.pkl')
# Out:
# Saved: english-Greek-both.pkl
# Saved: english-Greek-train.pkl
# Saved: english-Greek-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-Greek-both.pkl')
train = load_clean_sentences('english-Greek-train.pkl')
test = load_clean_sentences('english-Greek-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Greek  Vocabulary Size: %d' % ger_vocab_size)
print('Greek  Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2247
# English Max Length: 7
# Greek  Vocabulary Size: 4248
# Greek  Max Length: 8
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 8, 256)            1087488
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 7, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 7, 256)            525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 7, 2247)           577479
# =================================================================
# Total params: 2,715,591
# Trainable params: 2,715,591
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 - 32s - loss: 3.9383 - val_loss: 3.1543
#
# Epoch 00001: val_loss improved from inf to 3.15426, saving model to model.h5
# Epoch 2/100
# 141/141 - 25s - loss: 3.0540 - val_loss: 2.9532
#
# Epoch 00002: val_loss improved from 3.15426 to 2.95318, saving model to model.h5
# Epoch 3/100
# 141/141 - 25s - loss: 2.9169 - val_loss: 2.8327
#
# Epoch 00003: val_loss improved from 2.95318 to 2.83270, saving model to model.h5
# Epoch 4/100
# 141/141 - 25s - loss: 2.8125 - val_loss: 2.7396
#
# Epoch 00004: val_loss improved from 2.83270 to 2.73959, saving model to model.h5
# Epoch 5/100
# 141/141 - 25s - loss: 2.6972 - val_loss: 2.6145
#
# Epoch 00005: val_loss improved from 2.73959 to 2.61454, saving model to model.h5
# Epoch 6/100
# 141/141 - 25s - loss: 2.5871 - val_loss: 2.5300
#
# Epoch 00006: val_loss improved from 2.61454 to 2.52997, saving model to model.h5
# Epoch 7/100
# 141/141 - 25s - loss: 2.5142 - val_loss: 2.4333
#
# Epoch 00007: val_loss improved from 2.52997 to 2.43328, saving model to model.h5
# Epoch 8/100
# 141/141 - 25s - loss: 2.3976 - val_loss: 2.3238
#
# Epoch 00008: val_loss improved from 2.43328 to 2.32384, saving model to model.h5
# Epoch 9/100
# 141/141 - 25s - loss: 2.2925 - val_loss: 2.2301
#
# Epoch 00009: val_loss improved from 2.32384 to 2.23015, saving model to model.h5
# Epoch 10/100
# 141/141 - 25s - loss: 2.1860 - val_loss: 2.1158
#
# Epoch 00010: val_loss improved from 2.23015 to 2.11584, saving model to model.h5
# Epoch 11/100
# 141/141 - 25s - loss: 2.0696 - val_loss: 2.0005
#
# Epoch 00011: val_loss improved from 2.11584 to 2.00052, saving model to model.h5
# Epoch 12/100
# 141/141 - 25s - loss: 1.9376 - val_loss: 1.8575
#
# Epoch 00012: val_loss improved from 2.00052 to 1.85751, saving model to model.h5
# Epoch 13/100
# 141/141 - 25s - loss: 1.7924 - val_loss: 1.7121
#
# Epoch 00013: val_loss improved from 1.85751 to 1.71213, saving model to model.h5
# Epoch 14/100
# 141/141 - 25s - loss: 1.6579 - val_loss: 1.5853
#
# Epoch 00014: val_loss improved from 1.71213 to 1.58525, saving model to model.h5
# Epoch 15/100
# 141/141 - 24s - loss: 1.5308 - val_loss: 1.4705
#
# Epoch 00015: val_loss improved from 1.58525 to 1.47053, saving model to model.h5
# Epoch 16/100
# 141/141 - 25s - loss: 1.4080 - val_loss: 1.3562
#
# Epoch 00016: val_loss improved from 1.47053 to 1.35624, saving model to model.h5
# Epoch 17/100
# 141/141 - 25s - loss: 1.2949 - val_loss: 1.2561
#
# Epoch 00017: val_loss improved from 1.35624 to 1.25614, saving model to model.h5
# Epoch 18/100
# 141/141 - 25s - loss: 1.1903 - val_loss: 1.1623
#
# Epoch 00018: val_loss improved from 1.25614 to 1.16231, saving model to model.h5
# Epoch 19/100
# 141/141 - 25s - loss: 1.0949 - val_loss: 1.0684
#
# Epoch 00019: val_loss improved from 1.16231 to 1.06844, saving model to model.h5
# Epoch 20/100
# 141/141 - 25s - loss: 1.0073 - val_loss: 0.9955
#
# Epoch 00020: val_loss improved from 1.06844 to 0.99547, saving model to model.h5
# Epoch 21/100
# 141/141 - 25s - loss: 0.9234 - val_loss: 0.9203
#
# Epoch 00021: val_loss improved from 0.99547 to 0.92031, saving model to model.h5
# Epoch 22/100
# 141/141 - 25s - loss: 0.8442 - val_loss: 0.8515
#
# Epoch 00022: val_loss improved from 0.92031 to 0.85151, saving model to model.h5
# Epoch 23/100
# 141/141 - 25s - loss: 0.7711 - val_loss: 0.7909
#
# Epoch 00023: val_loss improved from 0.85151 to 0.79094, saving model to model.h5
# Epoch 24/100
# 141/141 - 25s - loss: 0.7054 - val_loss: 0.7370
#
# Epoch 00024: val_loss improved from 0.79094 to 0.73698, saving model to model.h5
# Epoch 25/100
# 141/141 - 25s - loss: 0.6450 - val_loss: 0.6773
#
# Epoch 00025: val_loss improved from 0.73698 to 0.67729, saving model to model.h5
# Epoch 26/100
# 141/141 - 25s - loss: 0.5910 - val_loss: 0.6370
#
# Epoch 00026: val_loss improved from 0.67729 to 0.63701, saving model to model.h5
# Epoch 27/100
# 141/141 - 25s - loss: 0.5420 - val_loss: 0.5873
#
# Epoch 00027: val_loss improved from 0.63701 to 0.58729, saving model to model.h5
# Epoch 28/100
# 141/141 - 25s - loss: 0.4906 - val_loss: 0.5499
#
# Epoch 00028: val_loss improved from 0.58729 to 0.54986, saving model to model.h5
# Epoch 29/100
# 141/141 - 25s - loss: 0.4485 - val_loss: 0.5135
#
# Epoch 00029: val_loss improved from 0.54986 to 0.51352, saving model to model.h5
# Epoch 30/100
# 141/141 - 25s - loss: 0.4099 - val_loss: 0.4776
#
# Epoch 00030: val_loss improved from 0.51352 to 0.47764, saving model to model.h5
# Epoch 31/100
# 141/141 - 25s - loss: 0.3706 - val_loss: 0.4496
#
# Epoch 00031: val_loss improved from 0.47764 to 0.44961, saving model to model.h5
# Epoch 32/100
# 141/141 - 25s - loss: 0.3363 - val_loss: 0.4223
#
# Epoch 00032: val_loss improved from 0.44961 to 0.42228, saving model to model.h5
# Epoch 33/100
# 141/141 - 25s - loss: 0.3083 - val_loss: 0.4007
#
# Epoch 00033: val_loss improved from 0.42228 to 0.40069, saving model to model.h5
# Epoch 34/100
# 141/141 - 25s - loss: 0.2804 - val_loss: 0.3776
#
# Epoch 00034: val_loss improved from 0.40069 to 0.37764, saving model to model.h5
# Epoch 35/100
# 141/141 - 25s - loss: 0.2569 - val_loss: 0.3649
#
# Epoch 00035: val_loss improved from 0.37764 to 0.36493, saving model to model.h5
# Epoch 36/100
# 141/141 - 25s - loss: 0.2376 - val_loss: 0.3385
#
# Epoch 00036: val_loss improved from 0.36493 to 0.33849, saving model to model.h5
# Epoch 37/100
# 141/141 - 25s - loss: 0.2160 - val_loss: 0.3229
#
# Epoch 00037: val_loss improved from 0.33849 to 0.32287, saving model to model.h5
# Epoch 38/100
# 141/141 - 25s - loss: 0.1978 - val_loss: 0.3083
#
# Epoch 00038: val_loss improved from 0.32287 to 0.30833, saving model to model.h5
# Epoch 39/100
# 141/141 - 25s - loss: 0.1806 - val_loss: 0.2936
#
# Epoch 00039: val_loss improved from 0.30833 to 0.29363, saving model to model.h5
# Epoch 40/100
# 141/141 - 25s - loss: 0.1646 - val_loss: 0.2823
#
# Epoch 00040: val_loss improved from 0.29363 to 0.28229, saving model to model.h5
# Epoch 41/100
# 141/141 - 25s - loss: 0.1502 - val_loss: 0.2759
#
# Epoch 00041: val_loss improved from 0.28229 to 0.27594, saving model to model.h5
# Epoch 42/100
# 141/141 - 25s - loss: 0.1387 - val_loss: 0.2648
#
# Epoch 00042: val_loss improved from 0.27594 to 0.26476, saving model to model.h5
# Epoch 43/100
# 141/141 - 25s - loss: 0.1290 - val_loss: 0.2568
#
# Epoch 00043: val_loss improved from 0.26476 to 0.25680, saving model to model.h5
# Epoch 44/100
# 141/141 - 25s - loss: 0.1201 - val_loss: 0.2529
#
# Epoch 00044: val_loss improved from 0.25680 to 0.25289, saving model to model.h5
# Epoch 45/100
# 141/141 - 25s - loss: 0.1121 - val_loss: 0.2439
#
# Epoch 00045: val_loss improved from 0.25289 to 0.24390, saving model to model.h5
# Epoch 46/100
# 141/141 - 25s - loss: 0.1047 - val_loss: 0.2394
#
# Epoch 00046: val_loss improved from 0.24390 to 0.23942, saving model to model.h5
# Epoch 47/100
# 141/141 - 25s - loss: 0.0982 - val_loss: 0.2323
#
# Epoch 00047: val_loss improved from 0.23942 to 0.23234, saving model to model.h5
# Epoch 48/100
# 141/141 - 25s - loss: 0.0923 - val_loss: 0.2336
#
# Epoch 00048: val_loss did not improve from 0.23234
# Epoch 49/100
# 141/141 - 25s - loss: 0.0878 - val_loss: 0.2258
#
# Epoch 00049: val_loss improved from 0.23234 to 0.22576, saving model to model.h5
# Epoch 50/100
# 141/141 - 25s - loss: 0.0830 - val_loss: 0.2215
#
# Epoch 00050: val_loss improved from 0.22576 to 0.22146, saving model to model.h5
# Epoch 51/100
# 141/141 - 25s - loss: 0.0789 - val_loss: 0.2250
#
# Epoch 00051: val_loss did not improve from 0.22146
# Epoch 52/100
# 141/141 - 25s - loss: 0.0818 - val_loss: 0.2206
#
# Epoch 00052: val_loss improved from 0.22146 to 0.22059, saving model to model.h5
# Epoch 53/100
# 141/141 - 25s - loss: 0.0750 - val_loss: 0.2227
#
# Epoch 00053: val_loss did not improve from 0.22059
# Epoch 54/100
# 141/141 - 25s - loss: 0.0722 - val_loss: 0.2174
#
# Epoch 00054: val_loss improved from 0.22059 to 0.21745, saving model to model.h5
# Epoch 55/100
# 141/141 - 25s - loss: 0.0665 - val_loss: 0.2128
#
# Epoch 00055: val_loss improved from 0.21745 to 0.21285, saving model to model.h5
# Epoch 56/100
# 141/141 - 25s - loss: 0.0628 - val_loss: 0.2076
#
# Epoch 00056: val_loss improved from 0.21285 to 0.20761, saving model to model.h5
# Epoch 57/100
# 141/141 - 25s - loss: 0.0588 - val_loss: 0.2062
#
# Epoch 00057: val_loss improved from 0.20761 to 0.20617, saving model to model.h5
# Epoch 58/100
# 141/141 - 25s - loss: 0.0575 - val_loss: 0.2071
#
# Epoch 00058: val_loss did not improve from 0.20617
# Epoch 59/100
# 141/141 - 25s - loss: 0.0558 - val_loss: 0.2048
#
# Epoch 00059: val_loss improved from 0.20617 to 0.20478, saving model to model.h5
# Epoch 60/100
# 141/141 - 25s - loss: 0.0619 - val_loss: 0.2175
#
# Epoch 00060: val_loss did not improve from 0.20478
# Epoch 61/100
# 141/141 - 25s - loss: 0.0764 - val_loss: 0.2372
#
# Epoch 00061: val_loss did not improve from 0.20478
# Epoch 62/100
# 141/141 - 25s - loss: 0.0765 - val_loss: 0.2244
#
# Epoch 00062: val_loss did not improve from 0.20478
# Epoch 63/100
# 141/141 - 25s - loss: 0.0649 - val_loss: 0.2104
#
# Epoch 00063: val_loss did not improve from 0.20478
# Epoch 64/100
# 141/141 - 25s - loss: 0.0559 - val_loss: 0.2062
#
# Epoch 00064: val_loss did not improve from 0.20478
# Epoch 65/100
# 141/141 - 25s - loss: 0.0498 - val_loss: 0.2022
#
# Epoch 00065: val_loss improved from 0.20478 to 0.20224, saving model to model.h5
# Epoch 66/100
# 141/141 - 25s - loss: 0.0474 - val_loss: 0.1996
#
# Epoch 00066: val_loss improved from 0.20224 to 0.19962, saving model to model.h5
# Epoch 67/100
# 141/141 - 25s - loss: 0.0452 - val_loss: 0.1991
#
# Epoch 00067: val_loss improved from 0.19962 to 0.19914, saving model to model.h5
# Epoch 68/100
# 141/141 - 25s - loss: 0.0440 - val_loss: 0.1980
#
# Epoch 00068: val_loss improved from 0.19914 to 0.19802, saving model to model.h5
# Epoch 69/100
# 141/141 - 25s - loss: 0.0432 - val_loss: 0.1992
#
# Epoch 00069: val_loss did not improve from 0.19802
# Epoch 70/100
# 141/141 - 25s - loss: 0.0426 - val_loss: 0.1987
#
# Epoch 00070: val_loss did not improve from 0.19802
# Epoch 71/100
# 141/141 - 25s - loss: 0.0421 - val_loss: 0.1991
#
# Epoch 00071: val_loss did not improve from 0.19802
# Epoch 72/100
# 141/141 - 25s - loss: 0.0418 - val_loss: 0.1984
#
# Epoch 00072: val_loss did not improve from 0.19802
# Epoch 73/100
# 141/141 - 25s - loss: 0.0417 - val_loss: 0.1991
#
# Epoch 00073: val_loss did not improve from 0.19802
# Epoch 74/100
# 141/141 - 25s - loss: 0.0414 - val_loss: 0.1996
#
# Epoch 00074: val_loss did not improve from 0.19802
# Epoch 75/100
# 141/141 - 25s - loss: 0.0414 - val_loss: 0.1995
#
# Epoch 00075: val_loss did not improve from 0.19802
# Epoch 76/100
# 141/141 - 25s - loss: 0.0413 - val_loss: 0.2000
#
# Epoch 00076: val_loss did not improve from 0.19802
# Epoch 77/100
# 141/141 - 25s - loss: 0.0443 - val_loss: 0.2109
#
# Epoch 00077: val_loss did not improve from 0.19802
# Epoch 78/100
# 141/141 - 25s - loss: 0.0875 - val_loss: 0.2563
#
# Epoch 00078: val_loss did not improve from 0.19802
# Epoch 79/100
# 141/141 - 25s - loss: 0.0918 - val_loss: 0.2273
#
# Epoch 00079: val_loss did not improve from 0.19802
# Epoch 80/100
# 141/141 - 25s - loss: 0.0624 - val_loss: 0.2109
#
# Epoch 00080: val_loss did not improve from 0.19802
# Epoch 81/100
# 141/141 - 25s - loss: 0.0472 - val_loss: 0.2030
#
# Epoch 00081: val_loss did not improve from 0.19802
# Epoch 82/100
# 141/141 - 25s - loss: 0.0404 - val_loss: 0.1987
#
# Epoch 00082: val_loss did not improve from 0.19802
# Epoch 83/100
# 141/141 - 25s - loss: 0.0381 - val_loss: 0.1984
#
# Epoch 00083: val_loss did not improve from 0.19802
# Epoch 84/100
# 141/141 - 25s - loss: 0.0366 - val_loss: 0.2003
#
# Epoch 00084: val_loss did not improve from 0.19802
# Epoch 85/100
# 141/141 - 25s - loss: 0.0367 - val_loss: 0.1996
#
# Epoch 00085: val_loss did not improve from 0.19802
# Epoch 86/100
# 141/141 - 25s - loss: 0.0364 - val_loss: 0.1993
#
# Epoch 00086: val_loss did not improve from 0.19802
# Epoch 87/100
# 141/141 - 25s - loss: 0.0364 - val_loss: 0.2009
#
# Epoch 00087: val_loss did not improve from 0.19802
# Epoch 88/100
# 141/141 - 25s - loss: 0.0356 - val_loss: 0.1992
#
# Epoch 00088: val_loss did not improve from 0.19802
# Epoch 89/100
# 141/141 - 25s - loss: 0.0358 - val_loss: 0.2001
#
# Epoch 00089: val_loss did not improve from 0.19802
# Epoch 90/100
# 141/141 - 25s - loss: 0.0362 - val_loss: 0.2005
#
# Epoch 00090: val_loss did not improve from 0.19802
# Epoch 91/100
# 141/141 - 25s - loss: 0.0363 - val_loss: 0.2001
#
# Epoch 00091: val_loss did not improve from 0.19802
# Epoch 92/100
# 141/141 - 25s - loss: 0.0361 - val_loss: 0.1988
#
# Epoch 00092: val_loss did not improve from 0.19802
# Epoch 93/100
# 141/141 - 25s - loss: 0.0359 - val_loss: 0.1995
#
# Epoch 00093: val_loss did not improve from 0.19802
# Epoch 94/100
# 141/141 - 25s - loss: 0.0368 - val_loss: 0.2034
#
# Epoch 00094: val_loss did not improve from 0.19802
# Epoch 95/100
# 141/141 - 25s - loss: 0.0463 - val_loss: 0.2174
#
# Epoch 00095: val_loss did not improve from 0.19802
# Epoch 96/100
# 141/141 - 25s - loss: 0.0584 - val_loss: 0.2248
#
# Epoch 00096: val_loss did not improve from 0.19802
# Epoch 97/100
# 141/141 - 25s - loss: 0.0579 - val_loss: 0.2171
#
# Epoch 00097: val_loss did not improve from 0.19802
# Epoch 98/100
# 141/141 - 25s - loss: 0.0481 - val_loss: 0.2062
#
# Epoch 00098: val_loss did not improve from 0.19802
# Epoch 99/100
# 141/141 - 25s - loss: 0.0392 - val_loss: 0.2021
#
# Epoch 00099: val_loss did not improve from 0.19802
# Epoch 100/100
# 141/141 - 25s - loss: 0.0371 - val_loss: 0.2027
#
# Epoch 00100: val_loss did not improve from 0.19802

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-Greek-both.pkl')
train = load_clean_sentences('english-Greek-train.pkl')
test = load_clean_sentences('english-Greek-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[Θέλω να φύγω από τη Βοστώνη], target=[I want to leave Boston], predicted=[i want to leave boston]
# src=[Είστε έτοιμοι], target=[Youre ready], predicted=[youre ready]
# src=[Πρέπει να βρεις δουλειά], target=[You must find work], predicted=[you must find work]
# src=[Είστε αδύναμοι], target=[Youre weak], predicted=[youre weak]
# src=[Ο Τομ εργάστηκε στην Αυστραλία], target=[Tom worked in Australia], predicted=[tom worked in australia]
# src=[Ο χρόνος επουλώνει τα τραύματα], target=[Time heals all wounds], predicted=[time heals all wounds]
# src=[Δεν τον θέλουμε], target=[We dont want it], predicted=[we dont want it]
# src=[Είσαι ακαταμάχητος], target=[Youre irresistible], predicted=[youre irresistible]
# src=[Μείνε στο αμάξι σου], target=[Stay in your car], predicted=[stay in your car]
# src=[Πρέπει να συνεργαστούμε], target=[We have to cooperate], predicted=[we have to cooperate]
# BLEU-1: 0.673660
# BLEU-2: 0.604706
# BLEU-3: 0.543726
# BLEU-4: 0.372739
# test
# src=[Δεν θα μείνω πολύ εδώ], target=[I wont stay here long], predicted=[i wont stay here long]
# src=[Δεν μπορώ να τον βρω], target=[I cant find it], predicted=[i cant find it]
# src=[Τον θυμάμαι καλά], target=[I remember him well], predicted=[i remember him well]
# src=[Αγόρασα στον Τομ ένα αυτοκινητάκι], target=[I bought Tom a toy car], predicted=[i bought tom a toy car]
# src=[Το κατέβασα], target=[I downloaded it], predicted=[i downloaded it]
# src=[Φοβήθηκα], target=[I was frightened], predicted=[i was frightened]
# src=[Γεννήθηκα το 2013], target=[I was born in 2013], predicted=[i was born in 2013]
# src=[Ο Τομ είναι γιατρός], target=[Tom is a physician], predicted=[tom is a doctor]
# src=[Έχω ένα λεπτό], target=[I have a minute], predicted=[i have a minute]
# src=[Είστε μπάτσοι], target=[Are you cops], predicted=[are you cops]
# BLEU-1: 0.648519
# BLEU-2: 0.578308
# BLEU-3: 0.520235
# BLEU-4: 0.353354

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 100:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-Greek-both.pkl')
train = load_clean_sentences('english-Greek-train.pkl')
test = load_clean_sentences('english-Greek-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[Θέλω να φύγω από τη Βοστώνη], target=[I want to leave Boston], predicted=[i want to leave boston]
# src=[Είστε έτοιμοι], target=[Youre ready], predicted=[youre ready]
# src=[Πρέπει να βρεις δουλειά], target=[You must find work], predicted=[you must find work]
# src=[Είστε αδύναμοι], target=[Youre weak], predicted=[youre weak]
# src=[Ο Τομ εργάστηκε στην Αυστραλία], target=[Tom worked in Australia], predicted=[tom worked in australia]
# src=[Ο χρόνος επουλώνει τα τραύματα], target=[Time heals all wounds], predicted=[time heals all wounds]
# src=[Δεν τον θέλουμε], target=[We dont want it], predicted=[we dont want it]
# src=[Είσαι ακαταμάχητος], target=[Youre irresistible], predicted=[youre irresistible]
# src=[Μείνε στο αμάξι σου], target=[Stay in your car], predicted=[stay in your car]
# src=[Πρέπει να συνεργαστούμε], target=[We have to cooperate], predicted=[we have to cooperate]
# src=[Μπορείτε να δανειστείτε τ αυτοκίνητό μου], target=[You may borrow my car], predicted=[you may borrow my car]
# src=[Πού ναι η γάτα], target=[Wheres the cat], predicted=[wheres the cat]
# src=[Το τσάι μου είναι πολύ γλυκό], target=[My tea is too sweet], predicted=[my tea is too sweet]
# src=[Η μπλούζα είναι καθαρή], target=[The blouse is clean], predicted=[the blouse is clean]
# src=[Ο Τομ είναι άδικος], target=[Tom is unfair], predicted=[tom is unfair]
# src=[Ήσαστε μόνοι], target=[Were you alone], predicted=[were you alone]
# src=[Μου αρέσει να παίζω σκάκι], target=[I enjoy chess], predicted=[i enjoy chess chess]
# src=[Ήμασταν χαρούμενες], target=[We were happy], predicted=[we were happy]
# src=[Χάρηκα], target=[Im pleased to meet you], predicted=[im pleased to you you]
# src=[Νικήσατε], target=[You won], predicted=[you won]
# src=[Ήταν υπομονετικός], target=[He was patient], predicted=[he was patient]
# src=[Υπάρχει μέσα χώρος], target=[Theres room inside], predicted=[theres room inside]
# src=[Βοηθήστε με να τον σηκώσω], target=[Help me lift it], predicted=[help me lift it]
# src=[Είσ απ την Αυστραλία], target=[Are you from Australia], predicted=[are you from australia]
# src=[Δεν είναι ποτέ χαρούμενοι], target=[Theyre never happy], predicted=[theyre never happy]
# src=[Δεν τις αντιπαθώ], target=[I dont dislike them], predicted=[i dont dislike them]
# src=[Δικό σας είναι εκείνο το μολύβι], target=[Is that pencil yours], predicted=[is that pencil yours]
# src=[Μας έχετε λείψει], target=[Weve missed you], predicted=[weve missed you]
# src=[Ο Τομ δε γελάει], target=[Tom isnt laughing], predicted=[tom isnt laughing]
# src=[Τις είπα για σας], target=[I told them about you], predicted=[i told them about you]
# src=[Κοίτα με], target=[Look at me], predicted=[look at me]
# src=[Κυνηγούσαν αλεπούδες], target=[They hunted foxes], predicted=[they hunted foxes]
# src=[Όλα θ αλλάξουν], target=[Everything will change], predicted=[everything will change]
# src=[Είστε ο σύζυγος της Μαίρης], target=[Are you Marys husband], predicted=[are you marys husband]
# src=[Είμαι η αδερφή του Τομ], target=[Im Toms sister], predicted=[im toms sister]
# src=[Τον έσπασες], target=[Did you break it], predicted=[did you break it]
# src=[Τα Γαλλικά σου είναι καλά], target=[Your French is good], predicted=[your french is good]
# src=[Αρνούμαι να το επιτρέψω], target=[I refuse to allow it], predicted=[i refuse to allow it]
# src=[Νίκησαν], target=[They won], predicted=[they won]
# src=[Είμαι χαρούμενη που μπόρεσα να βοηθήσω], target=[Im happy I could help], predicted=[im happy i could help]
# src=[Πρέπει να φύγω], target=[I should go], predicted=[i should go]
# src=[Τι έχω], target=[What do I have], predicted=[what do i have]
# src=[Σου αρέσει το καλοκαίρι], target=[Do you like summer], predicted=[do you like summer]
# src=[Ας τ αγνοήσουμε αυτό], target=[Lets ignore that], predicted=[lets ignore that]
# src=[Ο Τομ επισκεύασε το ποδήλατό μου], target=[Tom repaired my bicycle], predicted=[tom repaired my bicycle]
# src=[Είναι τέλεια τα Γαλλικά του Τομ], target=[Toms French is perfect], predicted=[toms french is perfect]
# src=[Ο Τομ δουλεύει για μια τράπεζα], target=[Tom works for a bank], predicted=[tom works for a bank]
# src=[Μ αρέσει να τρέχω], target=[I like to run], predicted=[i like to run]
# src=[Ο Τομ μπορεί να κολυμπήσει γρήγορα], target=[Tom can swim fast], predicted=[tom can swim fast]
# src=[Τον αγόρασα], target=[I bought it], predicted=[i bought it]
# src=[Μου αρέσει να μελετώ Γαλλικά], target=[I like to study French], predicted=[i like studying french french]
# src=[Είναι σπίτι τώρα], target=[Hes at home right now], predicted=[hes at home right now]
# src=[Δε θα είμαι εδώ], target=[I wont be here], predicted=[i wont be here]
# src=[Δε θα σαι μονάχος], target=[You wont be alone], predicted=[you wont be alone]
# src=[Ο Τομ δε θα μας πίστευε], target=[Tom wouldnt believe us], predicted=[tom wouldnt believe us]
# src=[Ας βοηθήσουμε ο ένας στον άλλο], target=[Lets help each other], predicted=[lets help each other]
# src=[Τις έχουμε δει], target=[Weve seen them], predicted=[weve seen them]
# src=[Θα σας περιμένουμε], target=[Well wait for you], predicted=[well wait for you]
# src=[Ο σκύλος είναι δικός μου], target=[The dog is mine], predicted=[the dog is mine]
# src=[Είσαι άρρωστος], target=[Youre sick], predicted=[youre sick]
# src=[Γιατί τον παντρεύτηκες], target=[Why did you marry him], predicted=[why did you marry him]
# src=[Μην παίζετε εδώ], target=[Dont play here], predicted=[dont play here]
# src=[Το κλειδί είναι πάνω στο τραπέζι], target=[The key is on the table], predicted=[the key is on the table]
# src=[Θέλω να μείνεις], target=[I want you to stay], predicted=[i want you to stay]
# src=[Σ άκουσα να τραγουδάς], target=[I heard you singing], predicted=[i heard you singing]
# src=[Ο Τομ σε εμπιστεύεται], target=[Tom trusts you], predicted=[tom trusts you]
# src=[Θα τις βρούμε], target=[Well find them], predicted=[well find them]
# src=[Θα καταλάβει ο Τομ], target=[Tomll understand], predicted=[tomll understand understand]
# src=[Μπλοφάρει ο Τομ], target=[Is Tom bluffing], predicted=[is tom bluffing]
# src=[Κάλεσα τον δικηγόρο μου], target=[I called my lawyer], predicted=[i called my lawyer]
# src=[Κάναμε πολύ θόρυβο], target=[We made a lot of noise], predicted=[we made a lot of noise]
# src=[Πού πηγαίνεις], target=[Where are you going], predicted=[where are you going]
# src=[Πρέπει να κρυφτώ], target=[I must hide], predicted=[i must hide]
# src=[Μου λειψε ο Τομ], target=[I missed Tom], predicted=[i missed tom]
# src=[Ο Τομ ζηλεύει], target=[Is Tom jealous], predicted=[is tom jealous]
# src=[Ο Τομ θα μείνει μαζί σας], target=[Tom will stay with you], predicted=[tom will stay with you]
# src=[Δεν καπνίζω], target=[I dont smoke], predicted=[i dont smoke]
# src=[Καλό δρόμο], target=[Have a nice trip], predicted=[have a nice trip]
# src=[Ελπίζω να βρουν τον Τομ], target=[I hope they find Tom], predicted=[i hope they find tom]
# src=[Αυτός έχει πολύ ωραίο αυτοκίνητο], target=[His car is really cool], predicted=[his car is really cool]
# src=[Δεν είσαι μαθητής], target=[You are not a student], predicted=[you are not a student]
# src=[Είναι δάσκαλοι], target=[They are teachers], predicted=[they are teachers]
# src=[Πώς μπορούμε να βρούμε τον Τομ], target=[How can we find Tom], predicted=[how can we find tom]
# src=[Ποιος θ αρχίσει], target=[Wholl start], predicted=[wholl start]
# src=[Σε είδα στην τηλεόραση], target=[I saw you on TV], predicted=[i saw you on tv]
# src=[Ο χρόνος θα δείξει], target=[Time will tell], predicted=[time will tell]
# src=[Θα περπατήσουμε], target=[Well walk], predicted=[well walk]
# src=[Είναι μαύρο τ αμάξι σου], target=[Is your car black], predicted=[is your car black]
# src=[Ο Τομ θα συνεργαστεί], target=[Tom will cooperate], predicted=[tom will cooperate]
# src=[Γιατί δε με βοηθάτε], target=[Why dont you help me], predicted=[why dont you help me]
# src=[Τι σε κάνει χαρούμενο], target=[What makes you happy], predicted=[what makes you happy]
# src=[Είμαι νέος], target=[Im young], predicted=[im young]
# src=[Ο Τομ έχει αρκετά λεφτά], target=[Tom has enough money], predicted=[tom has enough money]
# src=[Σταθήκαμε τυχερές], target=[We got lucky], predicted=[we got lucky]
# src=[Επίθεση], target=[Attack], predicted=[attack]
# src=[Είσαι απασχολημένη], target=[Are you busy], predicted=[are you busy]
# src=[Ο Τομ ήταν θυμωμένος], target=[Was Tom angry], predicted=[was tom angry]
# src=[Είναι χαρούμενη], target=[She is happy], predicted=[she is happy]
# src=[Είναι μικρός κι αδύναμος], target=[He is small and weak], predicted=[he is small and weak]
# src=[Χρειάζομαι τα κλειδιά μου], target=[I need my keys], predicted=[i need my keys]
# BLEU-1: 0.673660
# BLEU-2: 0.604706
# BLEU-3: 0.543726
# BLEU-4: 0.372739
# test
# src=[Δεν θα μείνω πολύ εδώ], target=[I wont stay here long], predicted=[i wont stay here long]
# src=[Δεν μπορώ να τον βρω], target=[I cant find it], predicted=[i cant find it]
# src=[Τον θυμάμαι καλά], target=[I remember him well], predicted=[i remember him well]
# src=[Αγόρασα στον Τομ ένα αυτοκινητάκι], target=[I bought Tom a toy car], predicted=[i bought tom a toy car]
# src=[Το κατέβασα], target=[I downloaded it], predicted=[i downloaded it]
# src=[Φοβήθηκα], target=[I was frightened], predicted=[i was frightened]
# src=[Γεννήθηκα το 2013], target=[I was born in 2013], predicted=[i was born in 2013]
# src=[Ο Τομ είναι γιατρός], target=[Tom is a physician], predicted=[tom is a doctor]
# src=[Έχω ένα λεπτό], target=[I have a minute], predicted=[i have a minute]
# src=[Είστε μπάτσοι], target=[Are you cops], predicted=[are you cops]
# src=[Φαίνεστε απογοητευμένες], target=[You seem disappointed], predicted=[you seem disappointed]
# src=[Μισώ το καραόκε], target=[I hate karaoke], predicted=[i hate karaoke]
# src=[Το δωμάτιο ήταν σκοτεινό], target=[The room was dark], predicted=[the room was dark]
# src=[Φοβάμαι πως όχι], target=[Im afraid not], predicted=[im afraid not]
# src=[Τους έκαψα], target=[I burned them], predicted=[i burned them]
# src=[Η σύζυγός του είναι Γαλλίδα], target=[His wife is French], predicted=[his wife is french]
# src=[Ο Τομ σ αγαπάει], target=[Tom loves you], predicted=[tom loves you]
# src=[Η Ρωσία είναι μεγάλη], target=[Russia is big], predicted=[russia is big]
# src=[Το ίδιο μου κάνει], target=[I dont care], predicted=[i dont care]
# src=[Δε θα τον χάσω], target=[I wont lose it], predicted=[i wont lose it]
# src=[Μη μ αφήσετε μόνη], target=[Dont leave me alone], predicted=[dont leave me alone]
# src=[Είναι διάσημος ο Τομ], target=[Is Tom famous], predicted=[is tom famous]
# src=[Αυτό το τραγούδι είναι για σας], target=[This song is for you], predicted=[this song is for you]
# src=[Το ξέρω πως είσαι ταλαντούχα], target=[I know youre talented], predicted=[i know youre talented]
# src=[Αγαπάω τη χώρα μου], target=[I love my country], predicted=[i love my country]
# src=[Θα μου λείψεις], target=[Ill miss you], predicted=[ill miss you]
# src=[Η απάντησή του ήταν αρνητική], target=[His reply was negative], predicted=[his reply was negative]
# src=[Σχεδόν κανείς δε το ξέρει αυτό], target=[Almost nobody knows this], predicted=[almost nobody knows this]
# src=[Δε θα μάθει κάνεις], target=[Nobodyll know], predicted=[nobodyll know]
# src=[Είμαι χοντρός], target=[Am I fat], predicted=[am i fat]
# src=[Ήμαστε απασχολημένοι], target=[We were busy], predicted=[we were busy]
# src=[Ο Τομ έπιασε την μπάλα], target=[Tom caught the ball], predicted=[tom caught the ball]
# src=[Πέθανε πριν από πέντε χρόνια], target=[He died five years ago], predicted=[he died five years ago]
# src=[Θέλω να είμαι ελεύθερη], target=[I want to be free], predicted=[i want to be free]
# src=[Αγνοήστε τον Τομ], target=[Ignore Tom], predicted=[ignore tom]
# src=[Είσαι ο σύζυγος της Μαίρης], target=[Are you Marys husband], predicted=[are you marys husband]
# src=[Μ αρέσει η παραλία], target=[I like the beach], predicted=[i like the beach]
# src=[Προειδοποιήστε τον Τομ], target=[Warn Tom], predicted=[warn tom]
# src=[Αυτό σύντομα άλλαξε], target=[That soon changed], predicted=[that soon changed]
# src=[Θα δεις], target=[You will see], predicted=[you will see]
# src=[Μιλάω Γαλλικά κάθε μέρα], target=[I speak French every day], predicted=[i speak french every day]
# src=[Ήμουν μόνος], target=[I was alone], predicted=[i was alone]
# src=[Τον λατρεύει], target=[She adores him], predicted=[she adores him]
# src=[Σας χρειαζόμαστε εδώ], target=[We need you here], predicted=[we need you here]
# src=[Πού είναι η απόδειξη], target=[Wheres the receipt], predicted=[wheres the receipt]
# src=[Λατρεύω το χιόνι], target=[I love snow], predicted=[i love snow]
# src=[Είμαι μαθητής], target=[Im a student], predicted=[im a student]
# src=[Οδηγεί γρήγορα], target=[He drives fast], predicted=[he drives fast]
# src=[Πάω να πάρω τον Τομ], target=[Im going to go get Tom], predicted=[im going to go get tom]
# src=[Κανείς δε ζει για πάντα], target=[Nobody lives forever], predicted=[nobody lives forever]
# src=[Αυτή είναι κόρη μου], target=[Shes my daughter], predicted=[shes is daughter]
# src=[Τι έκανες], target=[What did you do], predicted=[what did you do]
# src=[Είστε εκτός υπηρεσίας σήμερα το βράδυ], target=[Are you off duty tonight], predicted=[are you off duty tonight]
# src=[Φαίνεται χλωμός], target=[He looks pale], predicted=[he looks pale]
# src=[Έχει ο Τομ ποδήλατο], target=[Does Tom have a bicycle], predicted=[does tom have a bicycle]
# src=[Χτες ήταν Πέμπτη], target=[Yesterday was Thursday], predicted=[yesterday was thursday]
# src=[Πόσα πέθαναν], target=[How many died], predicted=[how many died]
# src=[Θα σας τις φέρω], target=[Ill bring them to you], predicted=[ill bring them to you]
# src=[Ήμουν χαρούμενος], target=[I was happy], predicted=[i was happy]
# src=[Θέλω λίγο χυμό πορτοκάλι], target=[I want some orange juice], predicted=[i want some orange juice]
# src=[Απέσπασα το πρώτο βραβείο], target=[I won the first prize], predicted=[i won the first prize]
# src=[Οι αληθινοί ήρωες είμαστε εμείς], target=[The real heroes are us], predicted=[the real heroes are us]
# src=[Μ αρέσει να λύνω μυστήρια], target=[I like solving mysteries], predicted=[i like solving mysteries]
# src=[Ο Τομ και η Μαίρη είναι νεκροί], target=[Tom and Mary are dead], predicted=[tom and mary are dead]
# src=[Μου αρέσουν τα φρούτα], target=[I like fruit], predicted=[i like fruit]
# src=[Δεν τα αντιπαθώ], target=[I dont dislike them], predicted=[i dont dislike them]
# src=[Τι κάνει], target=[Whats she doing], predicted=[whats she doing]
# src=[Τη ξέρεις], target=[Do you know her], predicted=[do you know her]
# src=[Δεν είμαι θυμωμένη με τον Τομ], target=[Im not angry with Tom], predicted=[im not angry with tom]
# src=[Μ αρέσει το τένις], target=[I like tennis], predicted=[i like tennis]
# src=[Μείνε εδώ], target=[Stay there], predicted=[stay there]
# src=[Για ποιον δουλεύετε], target=[Who are you working for], predicted=[who are you working for]
# src=[Αφήστε με να τελειώσω], target=[Let me finish], predicted=[let me finish]
# src=[Το δωμάτιο είναι πολύ βρόμικο], target=[The room is very dirty], predicted=[the room is very dirty]
# src=[Ο σκύλος μου είναι άσπρος], target=[My dog is white], predicted=[my dog is white]
# src=[Μείνε ακίνητος], target=[Stay still], predicted=[stay still]
# src=[Έλα έξω], target=[Come outside], predicted=[come outside]
# src=[Ήσασταν ευτυχισμένος], target=[Were you happy], predicted=[were you happy]
# src=[Είναι άσπρο], target=[Is it white], predicted=[is it white]
# src=[Παραιτήθηκα], target=[I resigned], predicted=[i resigned]
# src=[Είμαι διαβητικός], target=[I am diabetic], predicted=[i am diabetic]
# src=[Είσαι άστεγος], target=[Are you homeless], predicted=[are you homeless]
# src=[Είναι τρεισήμισι], target=[Its 330], predicted=[its 330]
# src=[Ο Τομ γνωρίζει ότι είμαι Καναδέζος], target=[Tom knows Im Canadian], predicted=[tom knows im canadian]
# src=[Δε φταίω εγώ], target=[Its not my fault], predicted=[its not my fault]
# src=[Δε μπορώ να πιώ αλκοόλ], target=[I cant drink alcohol], predicted=[i cant drink alcohol]
# src=[Ένα αυτοκίνητο χτύπησε τον Τομ], target=[A car hit Tom], predicted=[a car hit tom]
# src=[Τον αξίζω], target=[I deserve it], predicted=[i deserve it]
# src=[Δεν το αγόρασε κανένας], target=[Nobody bought it], predicted=[nobody bought it]
# src=[Ο Τομ απήγαγε τη Μαίρη], target=[Tom kidnapped Mary], predicted=[tom kidnapped mary]
# src=[Ο Τομ ακούει τη Μαίρη], target=[Tom listens to Mary], predicted=[tom listens to mary]
# src=[Ο Τομ πλέκει], target=[Tom knits], predicted=[tom knits]
# src=[Μπορώ να μιλήσω με τον Τομ], target=[May I speak with Tom], predicted=[may i speak with tom]
# src=[Έχετε τρεις επιλογές], target=[You have three choices], predicted=[you have three choices]
# src=[Πού ναι η απόδειξη], target=[Wheres the receipt], predicted=[wheres the receipt]
# src=[Ο Τομ αγαπάει το μπέιζμπολ], target=[Tom loves baseball], predicted=[tom loves baseball]
# src=[Σιχαίνομαι τον καφέ], target=[I hate coffee], predicted=[i hate coffee]
# src=[Θα το πάρουμε], target=[Well take it], predicted=[well take it]
# src=[Δάγκωσα τη γλώσσα μου], target=[I bit my tongue], predicted=[i bit my tongue]
# src=[Θα ρωτήσω τον Τομ], target=[Ill ask Tom], predicted=[ill ask tom]
# BLEU-1: 0.648519
# BLEU-2: 0.578308
# BLEU-3: 0.520235
# BLEU-4: 0.353354
